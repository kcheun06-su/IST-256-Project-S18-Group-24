# %%
import requests
import json
user_input_food = input("Please enter a ingredient you want to cook: ")
user_input_calories = input("Please enter calories range (ex:100-300): ")
app_id = "22fe6955"
url = "https://api.edamam.com/search?q="+user_input_food+"&app_id="+app_id+"&app_key=a8701478a52245bcee06a8c8333289a6&from=0&to=4&calories="+user_input_calories

response = requests.get(url)
recipe = response.json()

recipe
# Out:
# Please enter a ingredient you want to cook: chicken
# Please enter calories range (ex:100-300): 100
# {'count': 4052,
#  'from': 0,
#  'hits': [{'bookmarked': False,
#    'bought': False,
#    'recipe': {'calories': 84.03176539279998,
#     'cautions': [],
#     'dietLabels': ['Low-Carb'],
#     'digest': [{'daily': 8.612427217284925,
#       'hasRDI': True,
#       'label': 'Fat',
#       'schemaOrgTag': 'fatContent',
#       'sub': [{'daily': 8.006330307975999,
#         'hasRDI': True,
#         'label': 'Saturated',
#         'schemaOrgTag': 'saturatedFatContent',
#         'tag': 'FASAT',
#         'total': 1.6012660615952,
#         'unit': 'g'},
#        {'daily': 0.0,
#         'hasRDI': False,
#         'label': 'Trans',
#         'schemaOrgTag': 'transFatContent',
#         'tag': 'FATRN',
#         'total': 0.035902743270240005,
#         'unit': 'g'},
#        {'daily': 0.0,
#         'hasRDI': False,
#         'label': 'Monounsaturated',
#         'schemaOrgTag': None,
# ...

# %%
requests.get(url)
# Out:
# <Response [200]>
