# %%
import requests

user_location = input("Where are you right now? ")

params = {}
params["term"] = "grocery store"
params["location"] = user_location

token = "QpgOEI29NHp0IosYkVAneBhWrIKJBDpnfKmu1xEDua5Y1exka_FLmXcxzj9Ir7IcBtKMfqAY-QxYujYcTpRvmbeet0hzrU-KPAKD_BbrHiCdjKVVcWoD6R0D0S3vWnYx"
headers = {'Authorization': 'Bearer %s' % token}

url = "https://api.yelp.com/v3/businesses/search"
request = requests.get(url, params=params, headers=headers)

data = request.json()
data
# Out:
# Where are you right now? Syracuse, NY
# {'businesses': [{'alias': 'wegmans-syracuse-3',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'drugstores', 'title': 'Drugstores'}],
#    'coordinates': {'latitude': 43.04733, 'longitude': -76.22757},
#    'display_phone': '(315) 487-1581',
#    'distance': 7566.161531014315,
#    'id': 'O9dtjpSrD1O5q_TS4Jq7gA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L1igohZHBgPPSIWdpgdAvg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3325 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3325 W Genesee St', 'Syracuse, NY 13219'],
#     'state': 'NY',
#     'zip_code': '13219'},
#    'name': 'Wegmans',
#    'phone': '+13154871581',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 29,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/wegmans-syracuse-3?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'trader-joes-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0462637, 'longitude': -76.0706629},
#    'display_phone': '(315) 446-1629',
#    'distance': 5578.779247097634,
#    'id': 'MWgN8bDS74BrhYPExrYNXw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Tbs9Z981ShvTnf60wPWNtA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3422 Erie Blvd E',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3422 Erie Blvd E', 'Syracuse, NY 13214'],
#     'state': 'NY',
#     'zip_code': '13214'},
#    'name': "Trader Joe's",
#    'phone': '+13154461629',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 37,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/trader-joes-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'green-hills-farms-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'coordinates': {'latitude': 42.9843940734863,
#     'longitude': -76.1427917480469},
#    'display_phone': '(315) 492-1707',
#    'distance': 8620.618135308514,
#    'id': 'o3jOQT3RlFqZRRyMKDRF5A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XVQmjWy7UmpOZYxWm7W_lg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5933 S Salina St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['5933 S Salina St', 'Syracuse, NY 13205'],
#     'state': 'NY',
#     'zip_code': '13205'},
#    'name': 'Green Hills Farms',
#    'phone': '+13154921707',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/green-hills-farms-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'samirs-imported-foods-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.04739, 'longitude': -76.13892},
#    'display_phone': '(315) 422-1850',
#    'distance': 1630.8037996074054,
#    'id': 'vEhbSwhJ9qF2Iu0SGrcGQg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dW4gGJLOUtuo64dM6xw2SQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '811 E Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['811 E Genesee St', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': "Samir's Imported Foods",
#    'phone': '+13154221850',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 14,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/samirs-imported-foods-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'aldi-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.05209, 'longitude': -76.114674},
#    'display_phone': '',
#    'distance': 2038.5482701323338,
#    'id': 'oAaFUdeOOAPk2sUbxlhrNQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LMDIv9HZBt4rWWWEwiXczg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2015 Erie Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['2015 Erie Blvd', 'Syracuse, NY 13224'],
#     'state': 'NY',
#     'zip_code': '13224'},
#    'name': 'Aldi',
#    'phone': '',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 6,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/aldi-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'green-planet-grocery-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.04845, 'longitude': -76.2340399},
#    'display_phone': '(315) 488-7777',
#    'distance': 8101.676869545502,
#    'id': '39RNDecTLV_0N5q5If1BkA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UceCrIhAwduRZzQ-4zgRgg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3514 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3514 W Genesee St', 'Syracuse, NY 13219'],
#     'state': 'NY',
#     'zip_code': '13219'},
#    'name': 'Green Planet Grocery',
#    'phone': '+13154887777',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 15,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/green-planet-grocery-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'wegmans-pharmacy-east-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'drugstores', 'title': 'Drugstores'}],
#    'coordinates': {'latitude': 43.06882, 'longitude': -76.08731},
#    'display_phone': '(315) 437-1599',
#    'distance': 4072.233700457795,
#    'id': 'kB9KUkiiQl0RD2qv3estuw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UUtvNfvCtWF3ixyc6O1dew/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4256 James St',
#     'address2': None,
#     'address3': None,
#     'city': 'East Syracuse',
#     'country': 'US',
#     'display_address': ['4256 James St', 'East Syracuse, NY 13057'],
#     'state': 'NY',
#     'zip_code': '13057'},
#    'name': 'Wegmans Pharmacy',
#    'phone': '+13154371599',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 16,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/wegmans-pharmacy-east-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'price-rite-syracuse-2',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0501099, 'longitude': -76.1227188},
#    'display_phone': '',
#    'distance': 1686.6081339111204,
#    'id': 'dtPlN76FGq7WYl4kw1wE5Q',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hSfAt7P60AyY7oVQOzms-Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '117 Teall Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['117 Teall Ave', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': 'Price Rite',
#    'phone': '',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/price-rite-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'wegmans-fayetteville-2',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0333504787092,
#     'longitude': -76.0533677315363},
#    'display_phone': '(315) 446-1180',
#    'distance': 7419.056770910634,
#    'id': '11iVFLMeFOWHAg9az0DCVw',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pGlRuq3Ajml_Pfdn3tU_3Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6789 E Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Fayetteville',
#     'country': 'US',
#     'display_address': ['6789 E Genesee St', 'Fayetteville, NY 13066'],
#     'state': 'NY',
#     'zip_code': '13066'},
#    'name': 'Wegmans',
#    'phone': '+13154461180',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 99,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/wegmans-fayetteville-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'alamos-food-market-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0480608, 'longitude': -76.1548124},
#    'display_phone': '(315) 471-1371',
#    'distance': 2165.9595009103627,
#    'id': 'c2gkmIX-jF1Sjp_a-3T5fQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '128 Walton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['128 Walton St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': "Alamo's Food Market",
#    'phone': '+13154711371',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/alamos-food-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'wegmans-liverpool-3',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.123062, 'longitude': -76.169925},
#    'display_phone': '(315) 457-0514',
#    'distance': 7347.827105818287,
#    'id': 'pTRi1xwWc8tqxetVzJhLxA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hBHz_fS4XWEcBfQYHbzqjg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4979 W Taft Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Liverpool',
#     'country': 'US',
#     'display_address': ['4979 W Taft Rd', 'Liverpool, NY 13088'],
#     'state': 'NY',
#     'zip_code': '13088'},
#    'name': 'Wegmans',
#    'phone': '+13154570514',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 40,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/wegmans-liverpool-3?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'maria-hot-food-and-grocery-market-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.04017, 'longitude': -76.17206},
#    'display_phone': '(315) 299-6634',
#    'distance': 3795.260051830581,
#    'id': 'JPdsWrm5O_cgZYIqFi8ZXg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nyh-_0Iz8izmrMqAMl6w2A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '745 S Geddes St',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['745 S Geddes St', 'Syracuse, NY 13204'],
#     'state': 'NY',
#     'zip_code': '13204'},
#    'name': 'Maria Hot Food & Grocery Market',
#    'phone': '+13152996634',
#    'rating': 5.0,
#    'review_count': 1,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/maria-hot-food-and-grocery-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'wegmans-east-syracuse-2',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0697735796526,
#     'longitude': -76.0871992234395},
#    'display_phone': '(315) 437-1534',
#    'distance': 4057.132710050449,
#    'id': 'kufcTWb73Ka-YoBHWQjF9g',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NVw4c4Yaw3JCBgi6v_BY-w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '4256 James St',
#     'address2': '',
#     'address3': '',
#     'city': 'East Syracuse',
#     'country': 'US',
#     'display_address': ['4256 James St', 'East Syracuse, NY 13057'],
#     'state': 'NY',
#     'zip_code': '13057'},
#    'name': 'Wegmans',
#    'phone': '+13154371534',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 4,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/wegmans-east-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'asia-food-market-syracuse',
#    'categories': [{'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'intlgrocery', 'title': 'International Grocery'}],
#    'coordinates': {'latitude': 43.0500722676516,
#     'longitude': -76.1260036379099},
#    'display_phone': '(315) 478-9888',
#    'distance': 1431.5306420304262,
#    'id': 'nBzT2TePvvnI7C8fh00d8A',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mlU6rVs3njgajJ1uKEyxJQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1449 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['1449 Erie Blvd E', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': 'Asia Food Market',
#    'phone': '+13154789888',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 25,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/asia-food-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'tops-friendly-markets-syracuse-2',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.1187528955644,
#     'longitude': -76.1474520162374},
#    'display_phone': '(315) 458-0032',
#    'distance': 6399.442456474272,
#    'id': 'wDxfZvloDnzehXK4Euh4jQ',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '3803 Brewerton Rd N',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3803 Brewerton Rd N', 'Syracuse, NY 13212'],
#     'state': 'NY',
#     'zip_code': '13212'},
#    'name': 'Tops Friendly Markets',
#    'phone': '+13154580032',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tops-friendly-markets-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'syracuse-cooperative-market-syracuse',
#    'categories': [{'alias': 'healthmarkets', 'title': 'Health Markets'}],
#    'coordinates': {'latitude': 43.03174, 'longitude': -76.1164},
#    'display_phone': '(315) 472-1385',
#    'distance': 3692.584542665521,
#    'id': 'f14Bt6BhcA8qXanA78qoVQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WOnqqCI2d9qlYrAcH5vV7w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '618 Kensington Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['618 Kensington Rd', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': 'Syracuse Cooperative Market',
#    'phone': '+13154721385',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 9,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/syracuse-cooperative-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'lucky-7-grocery-and-deli-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'convenience', 'title': 'Convenience Stores'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.08236, 'longitude': -76.12325},
#    'display_phone': '(315) 463-0491',
#    'distance': 2502.0107708722644,
#    'id': 'qR5TQW00xkw8x8fejkjRVQ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XS5pMov3_WSX2Y4WKwsv9A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3100 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3100 Court St', 'Syracuse, NY 13206'],
#     'state': 'NY',
#     'zip_code': '13206'},
#    'name': 'Lucky 7 Grocery & Deli',
#    'phone': '+13154630491',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 11,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lucky-7-grocery-and-deli-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'thanos-import-market-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'},
#     {'alias': 'delis', 'title': 'Delis'}],
#    'coordinates': {'latitude': 43.053525, 'longitude': -76.141812},
#    'display_phone': '(315) 422-4085',
#    'distance': 1038.2740094611909,
#    'id': '_Ma0DVy0cf0KO8jIoNYugA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/09w44QfRmn3SAf7f5BxZhQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '105 Green St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['105 Green St', 'Syracuse, NY 13203'],
#     'state': 'NY',
#     'zip_code': '13203'},
#    'name': 'Thanos Import Market',
#    'phone': '+13154224085',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 13,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/thanos-import-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'aldi-syracuse-5',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0536808577006,
#     'longitude': -76.1705977097154},
#    'display_phone': '',
#    'distance': 2957.5861456026896,
#    'id': 'aJYceIUG8NwEgpHKekSEAw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/puBkEMXDU-og597TFboKMw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1055 West Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['1055 West Genesee St', 'Syracuse, NY 13204'],
#     'state': 'NY',
#     'zip_code': '13204'},
#    'name': 'Aldi',
#    'phone': '',
#    'price': '$$',
#    'rating': 3.0,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/aldi-syracuse-5?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'syracuse-corner-market-syracuse',
#    'categories': [{'alias': 'grocery', 'title': 'Grocery'}],
#    'coordinates': {'latitude': 43.0425604387104,
#     'longitude': -76.136498786509},
#    'display_phone': '',
#    'distance': 2141.881945586438,
#    'id': 'b_sjdVp-IFd9ZTXWXuZLSQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fy1hfU8UU8TWl1rURoaf_A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '701 S Crouse Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['701 S Crouse Ave', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': 'Syracuse Corner Market',
#    'phone': '',
#    'price': '$',
#    'rating': 2.5,
#    'review_count': 3,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/syracuse-corner-market-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'}],
#  'region': {'center': {'latitude': 43.061818547441845,
#    'longitude': -76.13594055175781}},
#  'total': 230}

# %%
import folium
import warnings
warnings.filterwarnings('ignore')

center = (data['businesses'][0]['coordinates']['latitude'],data['businesses'][0]['coordinates']['longitude'])

map = folium.Map(location = center, zoom_start = 12)

grocery_stores = data['businesses']

for grocery_store in grocery_stores:
    latitude = grocery_store['coordinates']['latitude']
    longitude = grocery_store['coordinates']['longitude']
    position = (latitude, longitude)
    annotation = grocery_store['name']
    marker = folium.Marker(location = position, popup = annotation)
    map.add_child(marker)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests

user_location = input("Where are you right now? ")

params = {}
params["term"] = "baked chicken"
params["location"] = user_location

token = "QpgOEI29NHp0IosYkVAneBhWrIKJBDpnfKmu1xEDua5Y1exka_FLmXcxzj9Ir7IcBtKMfqAY-QxYujYcTpRvmbeet0hzrU-KPAKD_BbrHiCdjKVVcWoD6R0D0S3vWnYx"
headers = {'Authorization': 'Bearer %s' % token}

url = "https://api.yelp.com/v3/businesses/search"
request = requests.get(url, params=params, headers=headers)

data = request.json()
data
# Out:
# Where are you right now? Syracuse, NY
# {'businesses': [{'alias': 'creole-soul-café-syracuse',
#    'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'coordinates': {'latitude': 43.0469251, 'longitude': -76.151666},
#    'display_phone': '(315) 530-4178',
#    'distance': 2110.9681567732846,
#    'id': '-G-8pTVcD6ZpWovNHEHvZA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8L3URjRe8hADgU4VzCEpRA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '128 E Jefferson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['128 E Jefferson St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': 'Creole Soul Café',
#    'phone': '+13155304178',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 58,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/creole-soul-caf%C3%A9-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'dinosaur-bar-b-que-syracuse-3',
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.052489, 'longitude': -76.154655},
#    'display_phone': '(315) 476-4937',
#    'distance': 1840.6775071995612,
#    'id': 'XRgHyiWi1dKW17VyyiyG_g',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fwR7hHjp4np_yWVk4apzVA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '246 W Willow St',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['246 W Willow St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': 'Dinosaur Bar-B-Que',
#    'phone': '+13154764937',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 1428,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/dinosaur-bar-b-que-syracuse-3?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'the-jamerican-diner-syracuse-2',
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'coordinates': {'latitude': 43.0483762180654,
#     'longitude': -76.1472917930867},
#    'display_phone': '(315) 424-7090',
#    'distance': 1756.3571315770155,
#    'id': 'QONR7jD4_HZLs21ye7_HlA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wLUVBzMfHU4CqO0AzRWWkg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '415 E Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['415 E Washington St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': 'The Jamerican Diner',
#    'phone': '+13154247090',
#    'price': '$$',
#    'rating': 3.0,
#    'review_count': 26,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/the-jamerican-diner-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'tullys-good-times-syracuse-2',
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 43.04812, 'longitude': -76.22894},
#    'display_phone': '(315) 488-9322',
#    'distance': 7713.716431037613,
#    'id': 'G0796k8EBlZ45PN9jK-H1A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FzkDE3nyDb-qs9D_beNs9w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3355 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3355 W Genesee St', 'Syracuse, NY 13219'],
#     'state': 'NY',
#     'zip_code': '13219'},
#    'name': "Tully's Good Times",
#    'phone': '+13154889322',
#    'price': '$$',
#    'rating': 3.0,
#    'review_count': 50,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tullys-good-times-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'tullys-good-times-erie-blvd-syracuse',
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.05608, 'longitude': -76.08906},
#    'display_phone': '(315) 449-9339',
#    'distance': 3886.5792089257766,
#    'id': 'pjU2HK-WF93elYGKoTmGUw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kCE-ABEJt4LTklf3vt7ZUQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '2943 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['2943 Erie Blvd E', 'Syracuse, NY 13224'],
#     'state': 'NY',
#     'zip_code': '13224'},
#    'name': "Tully's Good Times Erie Blvd",
#    'phone': '+13154499339',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 90,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tullys-good-times-erie-blvd-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'kelleys-bar-and-restaurant-syracuse-2',
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.016082, 'longitude': -76.184064},
#    'display_phone': '(315) 478-6773',
#    'distance': 6405.597004295766,
#    'id': 'g-q2qDAMMjMbt-eG5celHg',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/M6ALngqFt18O_uOtcapv1A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5076 Velasko Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['5076 Velasko Rd', 'Syracuse, NY 13215'],
#     'state': 'NY',
#     'zip_code': '13215'},
#    'name': "Kelley's Bar and Restaurant",
#    'phone': '+13154786773',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 47,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/kelleys-bar-and-restaurant-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'grotto-syracuse',
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.1351933, 'longitude': -76.129669},
#    'display_phone': '(315) 214-8911',
#    'distance': 8174.765506989335,
#    'id': 'ILaii0C7tV-H7BYogW5CNw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ePAyc8PdC-_uvBiXmkKlPw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '101 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['101 S Main St', 'Syracuse, NY 13212'],
#     'state': 'NY',
#     'zip_code': '13212'},
#    'name': 'Grotto',
#    'phone': '+13152148911',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 47,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/grotto-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'bbq-house-syracuse',
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'coordinates': {'latitude': 43.048801, 'longitude': -76.1401209},
#    'display_phone': '(315) 422-8880',
#    'distance': 1486.799163972026,
#    'id': '0ac6JttDU_jRaVqVB13bHQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sm7-U0ECMxoIU-vJ-sQ5zQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '725 E Fayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['725 E Fayette St', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': 'BBQ House',
#    'phone': '+13154228880',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 26,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/bbq-house-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'just-wing-it-syracuse',
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'coordinates': {'latitude': 43.04787, 'longitude': -76.18677},
#    'display_phone': '(315) 314-7978',
#    'distance': 4390.878952109644,
#    'id': 'P59kJ6CgGvSpUC1-_UIovw',
#    'image_url': '',
#    'is_closed': False,
#    'location': {'address1': '201 Milton Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['201 Milton Ave', 'Syracuse, NY 13204'],
#     'state': 'NY',
#     'zip_code': '13204'},
#    'name': 'Just Wing It',
#    'phone': '+13153147978',
#    'rating': 4.0,
#    'review_count': 4,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/just-wing-it-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'cugini-syracuse',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'coordinates': {'latitude': 43.0517107, 'longitude': -76.154277},
#    'display_phone': '(315) 477-1000',
#    'distance': 1866.204853052858,
#    'id': '4Pzt6ALwAesxXQzFIURnOw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/la21Y62LGRcabTUn5rh1zg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '230 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['230 W Genesee St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': 'Cugini',
#    'phone': '+13154771000',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 39,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/cugini-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'toninis-pizzeria-syracuse-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 43.1250155156366,
#     'longitude': -76.1015599966049},
#    'display_phone': '(315) 424-1313',
#    'distance': 7561.387225385654,
#    'id': 'y75au4JVtF0kvTc07qfOGw',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_vq-1vBobUukMyp1FXGL9Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '6059 E Taft Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['6059 E Taft Rd', 'Syracuse, NY 13212'],
#     'state': 'NY',
#     'zip_code': '13212'},
#    'name': "Tonini's Pizzeria",
#    'phone': '+13154241313',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 58,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/toninis-pizzeria-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'kfc-syracuse-6',
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'coordinates': {'latitude': 43.0481, 'longitude': -76.2342},
#    'display_phone': '(315) 487-8532',
#    'distance': 8128.00148065689,
#    'id': 'lVTDKi77MgZfoHKU6Suo8g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0_nbQnSgSGTgdT6p73F0iA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3520 W Genesee St',
#     'address2': '',
#     'address3': None,
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3520 W Genesee St', 'Syracuse, NY 13219'],
#     'state': 'NY',
#     'zip_code': '13219'},
#    'name': 'KFC',
#    'phone': '+13154878532',
#    'rating': 1.0,
#    'review_count': 5,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/kfc-syracuse-6?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'dominos-pizza-syracuse-2',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 43.02815, 'longitude': -76.11057},
#    'display_phone': '(315) 423-0333',
#    'distance': 4265.278845156592,
#    'id': 'k-l0PnOePVkP7tOMsmW4-Q',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pL-rFD4mRFYp_aWq2CuK4g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '329 Nottingham Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['329 Nottingham Rd', 'Syracuse, NY 13210'],
#     'state': 'NY',
#     'zip_code': '13210'},
#    'name': "Domino's Pizza",
#    'phone': '+13154230333',
#    'price': '$',
#    'rating': 3.0,
#    'review_count': 9,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/dominos-pizza-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'otro-cinco-syracuse',
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'coordinates': {'latitude': 43.0488693, 'longitude': -76.150832},
#    'display_phone': '(315) 422-6876',
#    'distance': 1880.7422129879221,
#    'id': 'MVJxQrxea2wgGlDcqQratg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t9MDp-vT-pxR2VDaSso3ug/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '206 S Warren St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['206 S Warren St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': 'Otro Cinco',
#    'phone': '+13154226876',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 198,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/otro-cinco-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'ale-n-angus-pub-syracuse',
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.0442478044981,
#     'longitude': -76.1490670393199},
#    'display_phone': '(315) 426-9672',
#    'distance': 2225.9353292652913,
#    'id': 'GKWuuwGy8KDs4lbJX7D-4g',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JFO3Lp7Dvj61O7VQFOKmDw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '238 Harrison St',
#     'address2': None,
#     'address3': None,
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['238 Harrison St', 'Syracuse, NY 13202'],
#     'state': 'NY',
#     'zip_code': '13202'},
#    'name': "Ale 'n' Angus Pub",
#    'phone': '+13154269672',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 33,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ale-n-angus-pub-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'good-news-cafe-syracuse-2',
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.048672, 'longitude': -76.232681},
#    'display_phone': '(315) 471-0860',
#    'distance': 7992.426018587672,
#    'id': 'LYzoCrW8M8rsHlTeGRq_FA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Fw609jCLDTdFYlu868cnfQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3508 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3508 W Genesee St', 'Syracuse, NY 13219'],
#     'state': 'NY',
#     'zip_code': '13219'},
#    'name': 'Good News Cafe',
#    'phone': '+13154710860',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 12,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/good-news-cafe-syracuse-2?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'tonys-family-restaurant-syracuse',
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 43.0601399, 'longitude': -76.0953},
#    'display_phone': '(315) 432-1030',
#    'distance': 3296.2233574613438,
#    'id': 'K6MVZpk5xzcPu3BKeChZbA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8ADKpcfcQ33u72_WKDNCDQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3004 Burnet Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3004 Burnet Ave', 'Syracuse, NY 13206'],
#     'state': 'NY',
#     'zip_code': '13206'},
#    'name': "Tony's Family Restaurant",
#    'phone': '+13154321030',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 16,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tonys-family-restaurant-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'san-remo-pizza-syracuse',
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'coordinates': {'latitude': 43.1358, 'longitude': -76.17058},
#    'display_phone': '(315) 451-0999',
#    'distance': 8679.482361920545,
#    'id': '6DsAKRIqqMOE_v4niHJAdQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iOhuYR-sFL96iqjQVPYPGQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '7575 Buckley Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['7575 Buckley Rd', 'Syracuse, NY 13212'],
#     'state': 'NY',
#     'zip_code': '13212'},
#    'name': 'San Remo Pizza',
#    'phone': '+13154510999',
#    'price': '$',
#    'rating': 3.5,
#    'review_count': 19,
#    'transactions': ['pickup', 'delivery'],
#    'url': 'https://www.yelp.com/biz/san-remo-pizza-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'},
#   {'alias': 'texas-roadhouse-syracuse',
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'coordinates': {'latitude': 43.05556, 'longitude': -76.07719},
#    'display_phone': '(315) 445-4086',
#    'distance': 5406.415074687612,
#    'id': 'eJbhFy469iMzyj5XJw344A',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gd7fV3uEgAttSFdN849CXg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '3143 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'country': 'US',
#     'display_address': ['3143 Erie Blvd E', 'Syracuse, NY 13214'],
#     'state': 'NY',
#     'zip_code': '13214'},
#    'name': 'Texas Roadhouse',
#    'phone': '+13154454086',
#    'price': '$$',
#    'rating': 3.5,
#    'review_count': 80,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/texas-roadhouse-syracuse?adjust_creative=nd8E-ENnmQPB7dGmYrkHZw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=nd8E-ENnmQPB7dGmYrkHZw'}],
#  'region': {'center': {'latitude': 43.061818547441845,
#    'longitude': -76.13594055175781}},
#  'total': 84}
