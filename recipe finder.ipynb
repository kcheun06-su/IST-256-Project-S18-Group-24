# %%
import requests
import json

# %%
user_input_food = input("Please enter a ingredient you want to cook: ")
user_input_calories = input("Please enter calories range (ex:100-300): ")
app_id = "22fe6955"
url = "https://api.edamam.com/search?q="+user_input_food+"&app_id="+app_id+"&app_key=a8701478a52245bcee06a8c8333289a6&from=0&to=4&calories="+user_input_calories+"&health=alcohol-free"

response = requests.get(url)
recipe = response.json()

recipe
# Out:
# Please enter a ingredient you want to cook: chicken
# Please enter calories range (ex:100-300): 200
# {'count': 18936,
#  'from': 0,
#  'hits': [{'bookmarked': False,
#    'bought': False,
#    'recipe': {'calories': 1122.2360945849998,
#     'cautions': [],
#     'dietLabels': ['Low-Carb'],
#     'digest': [{'daily': 121.8603342920769,
#       'hasRDI': True,
#       'label': 'Fat',
#       'schemaOrgTag': 'fatContent',
#       'sub': [{'daily': 107.82674379870002,
#         'hasRDI': True,
#         'label': 'Saturated',
#         'schemaOrgTag': 'saturatedFatContent',
#         'tag': 'FASAT',
#         'total': 21.565348759740004,
#         'unit': 'g'},
#        {'daily': 0.0,
#         'hasRDI': False,
#         'label': 'Trans',
#         'schemaOrgTag': 'transFatContent',
#         'tag': 'FATRN',
#         'total': 0.404831190225,
#         'unit': 'g'},
#        {'daily': 0.0,
#         'hasRDI': False,
#         'label': 'Monounsaturated',
#         'schemaOrgTag': None,
# ...
